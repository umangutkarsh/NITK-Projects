# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df = pd.read_csv('kc_house_data.csv')

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %%
plt.figure(figsize=(20,8))
sns.displot(df['price'],kde=True)

# %%
sns.countplot(df['bedrooms'])
# Out:
# C:\Users\UMANG\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bedrooms', ylabel='count'>

# %%
df.corr()['price'].sort_values()
# Out:
# zipcode         -0.053402
# id              -0.016772
# long             0.022036
# condition        0.036056
# yr_built         0.053953
# sqft_lot15       0.082845
# sqft_lot         0.089876
# yr_renovated     0.126424
# floors           0.256804
# waterfront       0.266398
# lat              0.306692
# bedrooms         0.308787
# sqft_basement    0.323799
# view             0.397370
# bathrooms        0.525906
# sqft_living15    0.585241
# sqft_above       0.605368
# grade            0.667951
# sqft_living      0.701917
# price            1.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10,8))

sns.scatterplot(x='price',y='sqft_living',data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='sqft_living'>

# %%
plt.figure(figsize=(10,8))

sns.scatterplot(x='price',y='sqft_above',data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='sqft_above'>

# %%
plt.figure(figsize=(10,8))

sns.boxplot(x='bedrooms',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %%
plt.figure(figsize=(10,8))

sns.countplot(x='floors',data=df)
# Out:
# <AxesSubplot:xlabel='floors', ylabel='count'>

# %%
plt.figure(figsize=(12,8))

sns.scatterplot(x='price',y='long',data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='long'>

# %%
plt.figure(figsize=(12,8))

sns.scatterplot(x='price',y='lat',data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='lat'>

# %%
plt.figure(figsize=(12,8))

sns.scatterplot(x='long',y='lat',data=df,hue='price')
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
df.sort_values('price',ascending=False).head(51)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %%
len(df)*0.02
# Out:
# 431.94

# %%
bottom_98perc = df.sort_values('price',ascending=False).iloc[432:]

# %%
bottom_98perc
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 20436  1125079111  4/15/2015  1600000.0         4       5.50         6530
# 12088  8655000070   6/1/2014  1600000.0         5       3.00         3640
# 19912  6600000217   4/3/2015  1600000.0         4       4.25         4645
# 2618   2624059036  10/3/2014  1600000.0         5       4.50         5130
# 16287  1130000005  7/15/2014  1600000.0         3       2.25         3170
# ...           ...        ...        ...       ...        ...          ...
# 2139   1623049041   5/8/2014    82500.0         2       1.00          520
# 8267   3883800011  11/5/2014    82000.0         3       1.00          860
# 16184  3028200080  3/24/2015    81000.0         2       1.00          730
# 465    8658300340  5/23/2014    80000.0         1       0.75          430
# 15279    40000362   5/6/2014    78000.0         2       1.00          780
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
plt.figure(figsize=(12,8))

sns.scatterplot(x='long',y='lat',data=bottom_98perc,hue='price')
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
plt.figure(figsize=(12,8))

sns.scatterplot(x='long',y='lat',data=bottom_98perc,hue='price',edgecolor=None,palette='RdYlGn',alpha=0.4)
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
sns.boxplot(x='waterfront',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='waterfront', ylabel='price'>

# %%
sns.boxplot(x='waterfront',y='price',data=bottom_99perc)
# Out:
# <AxesSubplot:xlabel='waterfront', ylabel='price'>

# %%
df = df.drop('id',axis=1)

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['date']
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21592   2014-05-21
# 21593   2015-02-23
# 21594   2014-06-23
# 21595   2015-01-16
# 21596   2014-10-15
# Name: date, Length: 21597, dtype: datetime64[ns]

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
# ...

# %%
df['year'] = df['date'].apply(lambda date : date.year)
df['month'] = df['date'].apply(lambda date : date.month)

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %%
plt.figure(figsize=(12,8))

sns.boxplot(x='month',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='month', ylabel='price'>

# %%
df.groupby('month').mean()['price'].plot()
# Out:
# <AxesSubplot:xlabel='month'>

# %%
df.groupby('year').mean()['price'].plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df.drop('date',axis=1)
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21592  360000.0         3       2.50         1530      1131     3.0
# 21593  400000.0         4       2.50         2310      5813     2.0
# 21594  402101.0         2       0.75         1020      1350     2.0
# 21595  400000.0         3       2.50         1600      2388     2.0
# 21596  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  ...  sqft_basement  yr_built  \
# 0               0     0          3      7  ...              0      1955
# ...

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %%
df['zipcode'].value_counts()
# Out:
# 98103    602
# 98038    589
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    104
# 98010    100
# 98024     80
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',hue='zipcode',data=df)
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
df = df.drop('zipcode',axis=1)

# %%
df['yr_renovated'].value_counts()
# Out:
# 0       20683
# 2014       91
# 2013       37
# 2003       36
# 2007       35
#         ...
# 1948        1
# 1954        1
# 1951        1
# 1944        1
# 1959        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
df[df['yr_renovated']!=0]['yr_renovated']
# Out:
# 1        1991
# 35       2002
# 95       1991
# 103      2010
# 115      1999
#          ...
# 19606    1960
# 20041    2006
# 20428    2009
# 20431    2014
# 20946    2007
# Name: yr_renovated, Length: 914, dtype: int64

# %%
def renovation(value):
    if value!=0:
        return 1
    else:
        return 0

# %%
df['renovation'] = df['yr_renovated'].apply(renovation)

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %%
df['sqft_basement'].value_counts()
# Out:
# 0       13110
# 600       221
# 700       218
# 500       214
# 800       206
#         ...
# 65          1
# 1248        1
# 172         1
# 1920        1
# 1135        1
# Name: sqft_basement, Length: 306, dtype: int64

# %%
df.drop('renovation',axis=1,inplace=True)

# %%
df
# Out:
#             date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0     2014-10-13  221900.0         3       1.00         1180      5650
# 1     2014-12-09  538000.0         3       2.25         2570      7242
# 2     2015-02-25  180000.0         2       1.00          770     10000
# 3     2014-12-09  604000.0         4       3.00         1960      5000
# 4     2015-02-18  510000.0         3       2.00         1680      8080
# ...          ...       ...       ...        ...          ...       ...
# 21592 2014-05-21  360000.0         3       2.50         1530      1131
# 21593 2015-02-23  400000.0         4       2.50         2310      5813
# 21594 2014-06-23  402101.0         2       0.75         1020      1350
# 21595 2015-01-16  400000.0         3       2.50         1600      2388
# 21596 2014-10-15  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  ...  sqft_above  sqft_basement  \
# ...

# %%
df.drop('date',axis=1,inplace=True)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %%
bottom_98perc.drop(['id','zipcode'],axis=1,inplace=True)

# %%
bottom_98perc
# Out:
#             date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 20436 2015-04-15  1600000.0         4       5.50         6530    871200
# 12088 2014-06-01  1600000.0         5       3.00         3640      8239
# 19912 2015-04-03  1600000.0         4       4.25         4645      7757
# 2618  2014-10-03  1600000.0         5       4.50         5130     43123
# 16287 2014-07-15  1600000.0         3       2.25         3170      5000
# ...          ...        ...       ...        ...          ...       ...
# 2139  2014-05-08    82500.0         2       1.00          520     22334
# 8267  2014-11-05    82000.0         3       1.00          860     10426
# 16184 2015-03-24    81000.0         2       1.00          730      9975
# 465   2014-05-23    80000.0         1       0.75          430      5050
# 15279 2014-05-06    78000.0         2       1.00          780     16344
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
bottom_98perc['date'] = pd.to_datetime(bottom_98perc['date'])

# %%
bottom_98perc['year'] = bottom_98perc['date'].apply(lambda date : date.year)
bottom_98perc['month'] = bottom_98perc['date'].apply(lambda date : date.month)

# %%
bottom_98perc.drop('date',axis=1,inplace=True)

# %%
bottom_98perc
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 20436  1600000.0         4       5.50         6530    871200     2.0
# 12088  1600000.0         5       3.00         3640      8239     2.0
# 19912  1600000.0         4       4.25         4645      7757     2.0
# 2618   1600000.0         5       4.50         5130     43123     2.0
# 16287  1600000.0         3       2.25         3170      5000     2.0
# ...          ...       ...        ...          ...       ...     ...
# 2139     82500.0         2       1.00          520     22334     1.0
# 8267     82000.0         3       1.00          860     10426     1.0
# 16184    81000.0         2       1.00          730      9975     1.0
# 465      80000.0         1       0.75          430      5050     1.0
# 15279    78000.0         2       1.00          780     16344     1.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
X = bottom_98perc.drop('price',axis=1).values
y = bottom_98perc['price'].values

# %%
X
# Out:
# array([[4.00000e+00, 5.50000e+00, 6.53000e+03, ..., 8.58132e+05,
#         2.01500e+03, 4.00000e+00],
#        [5.00000e+00, 3.00000e+00, 3.64000e+03, ..., 1.06430e+04,
#         2.01400e+03, 6.00000e+00],
#        [4.00000e+00, 4.25000e+00, 4.64500e+03, ..., 6.97000e+03,
#         2.01500e+03, 4.00000e+00],
#        ...,
#        [2.00000e+00, 1.00000e+00, 7.30000e+02, ..., 9.00000e+03,
#         2.01500e+03, 3.00000e+00],
#        [1.00000e+00, 7.50000e-01, 4.30000e+02, ..., 7.50000e+03,
#         2.01400e+03, 5.00000e+00],
#        [2.00000e+00, 1.00000e+00, 7.80000e+02, ..., 1.03870e+04,
#         2.01400e+03, 5.00000e+00]])

# %%
y
# Out:
# array([1600000., 1600000., 1600000., ...,   81000.,   80000.,   78000.])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[0.33333333, 0.32      , 0.25457103, ..., 0.00447878, 0.        ,
#         1.        ],
#        [0.22222222, 0.24      , 0.19971871, ..., 0.04521744, 0.        ,
#         0.45454545],
#        [0.44444444, 0.32      , 0.25738397, ..., 0.00393889, 0.        ,
#         0.45454545],
#        ...,
#        [0.22222222, 0.32      , 0.19127989, ..., 0.00670726, 0.        ,
#         0.72727273],
#        [0.22222222, 0.28      , 0.14486639, ..., 0.00364598, 0.        ,
#         0.63636364],
#        [0.33333333, 0.48      , 0.30379747, ..., 0.0061444 , 0.        ,
#         0.63636364]])

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[0.33333333, 0.32      , 0.27707454, ..., 0.003847  , 0.        ,
#         0.45454545],
#        [0.11111111, 0.08      , 0.09001406, ..., 0.00407674, 0.        ,
#         0.36363636],
#        [0.33333333, 0.2       , 0.12939522, ..., 0.00393889, 0.        ,
#         0.45454545],
#        ...,
#        [0.33333333, 0.28      , 0.2883263 , ..., 0.0096307 , 0.        ,
#         0.54545455],
#        [0.22222222, 0.08      , 0.11533052, ..., 0.01045203, 0.        ,
#         0.72727273],
#        [0.33333333, 0.08      , 0.18002813, ..., 0.01086785, 0.        ,
#         0.90909091]])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
X_train.shape
# Out:
# (14815, 19)

# %%
X_test.shape
# Out:
# (6350, 19)

# %%
model = Sequential()

model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))

model.add(Dense(1))

model.compile(optimizer='adam',loss='mse')

# %%
model.fit(x=X_train,y=y_train,
          validation_data=(X_test,y_test),batch_size=128,epochs=400)
# Out:
# Epoch 1/400
# 116/116 [==============================] - 1s 2ms/step - loss: 318687543296.0000 - val_loss: 328013414400.0000
# Epoch 2/400
# 116/116 [==============================] - 0s 2ms/step - loss: 316360392704.0000 - val_loss: 320129761280.0000
# Epoch 3/400
# 116/116 [==============================] - 0s 2ms/step - loss: 288546029568.0000 - val_loss: 259026239488.0000
# Epoch 4/400
# 116/116 [==============================] - 0s 2ms/step - loss: 180858650624.0000 - val_loss: 108065464320.0000
# Epoch 5/400
# 116/116 [==============================] - 0s 2ms/step - loss: 60931383296.0000 - val_loss: 45468295168.0000
# Epoch 6/400
# 116/116 [==============================] - 0s 2ms/step - loss: 42326614016.0000 - val_loss: 43831119872.0000
# Epoch 7/400
# 116/116 [==============================] - 0s 2ms/step - loss: 41431457792.0000 - val_loss: 42932170752.0000
# Epoch 8/400
# ...

# %%
pd.DataFrame(model.history.history)
# Out:
#              loss      val_loss
# 0    3.186875e+11  3.280134e+11
# 1    3.163604e+11  3.201298e+11
# 2    2.885460e+11  2.590262e+11
# 3    1.808587e+11  1.080655e+11
# 4    6.093138e+10  4.546830e+10
# ..            ...           ...
# 395  1.693721e+10  1.777622e+10
# 396  1.695553e+10  1.778723e+10
# 397  1.694671e+10  1.777427e+10
# 398  1.694275e+10  1.784486e+10
# 399  1.693323e+10  1.777013e+10
#
# [400 rows x 2 columns]

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,explained_variance_score

# %%
prediction = model.predict(X_test)

# %%
prediction
# Out:
# array([[428897.75],
#        [499329.84],
#        [573089.7 ],
#        ...,
#        [817513.8 ],
#        [226309.48],
#        [326868.3 ]], dtype=float32)

# %%
y_test
# Out:
# array([445000., 500000., 549000., ..., 945000., 215000., 282500.])

# %%
mean_absolute_error(y_test,prediction)
# Out:
# 92285.0409128937

# %%
mean_squared_error(y_test,prediction)
# Out:
# 17770123839.937283

# %%
mean_squared_error(y_test,prediction)**0.5
# Out:
# 133304.6279764408

# %%
df['price'].describe()
# Out:
# count    2.159700e+04
# mean     5.402966e+05
# std      3.673681e+05
# min      7.800000e+04
# 25%      3.220000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
5.402966e+05
# Out:
# 540296.6

# %%
plt.figure(figsize=(12,8))
plt.scatter(x=y_test,y=prediction)
plt.plot(y_test,y_test,'g')

# %%
explained_variance_score(y_test,prediction)
# Out:
# 0.7371927308742954

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %%
new_house = df.drop('price',axis=1).iloc[0]

# %%
new_house = scaler.transform(new_house.values.reshape(-1,19))

# %%
model.predict(new_house)
# Out:
# array([[279978.84]], dtype=float32)

# %%
new_house2 = df.drop('price',axis=1).iloc[1]

# %%
new_house2 = scaler.transform(new_house2.values.reshape(-1,19))

# %%
model.predict(new_house2)
# Out:
# array([[647085.7]], dtype=float32)

# %%
df.head(2)
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
#
#        lat     long  sqft_living15  sqft_lot15  year  month
# 0  47.5112 -122.257           1340        5650  2014     10
# 1  47.7210 -122.319           1690        7639  2014     12
